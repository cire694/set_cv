# %%
from PIL import Image
from test_model import predict

# %%
image_path = "../data/1113/0.jpg"
img = Image.open(image_path)
img.show()

predict(image_path)
# Out:
# {'color': 'Red', 'number': '1', 'shape': 'Diamond', 'fill': 'Empty'}
