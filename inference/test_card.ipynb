# %%
from PIL import Image
from predict import predict

# %%
image_path = "../data/3331/0.jpg"
img = Image.open(image_path)
img.show()

string, raw = predict(image_path)
print(raw, string)
# Out:
# 3331 {'color': 'Purple', 'number': '3', 'shape': 'Squiggle', 'fill': 'Empty'}
